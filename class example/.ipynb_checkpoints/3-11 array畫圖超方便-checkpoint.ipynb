# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(50)
#取0到1之間的亂數

# %%
y
# Out:
# array([0.61916739, 0.86152768, 0.98042982, 0.61707019, 0.34793458,
#        0.61483073, 0.90418422, 0.41043447, 0.24295433, 0.75379794,
#        0.31045502, 0.87539114, 0.22669964, 0.82630397, 0.03154027,
#        0.39444242, 0.03587393, 0.43805176, 0.98245544, 0.78157493,
#        0.04515282, 0.60486259, 0.96816416, 0.3002507 , 0.98670161,
#        0.0846994 , 0.74800513, 0.09060457, 0.49048093, 0.69469384,
#        0.72712052, 0.40686547, 0.46746249, 0.5442912 , 0.42639343,
#        0.62802303, 0.35173094, 0.73252762, 0.46745031, 0.27866911,
#        0.74618874, 0.33449463, 0.07901054, 0.00619834, 0.61317374,
#        0.7230172 , 0.25278274, 0.51602129, 0.12920285, 0.14535437])

# %%
plt.plot(y)

# %%
x = np.linspace(0, 10, 100)
#描點法的第一步 建立一連串的點：x = np.linspace(起始點, 結束值, 多少點)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x, np.sin(x)+x)

# %%
plt.plot(x, np.sin(x)+x)
plt.plot(x, np.cos(x))
