# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2, 10, 3, 13, 5])

# %%
randn(10)
# Out:
# array([ 0.10326717, -1.0959183 ,  1.59705888,  1.12644684,  0.25438103,
#        -0.10664719, -0.4858724 , -0.60846473, -0.42682949,  0.33791745])

# %%
plot(randn(100))

# %%
plot([-2, 1, 2.7, 3.3], [3, -5, 6, 0])
