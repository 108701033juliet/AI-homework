# %%
# %matplotlib inline  
#讓 jupyter notebook 能夠出現matplotlib的圖片
import numpy as np
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([3, -4, 8, 9, -10, 19])

# %%
plt.plot(np.random.randn(100))

# %% [markdown]
# 善用tab鍵
